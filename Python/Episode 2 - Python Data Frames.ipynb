# %% [markdown]
# # Mejores prácticas en Ciencia de Datos

# %% [markdown]
# ## Python Data Frames

# %% [markdown]
# Autor                        | Año             | Lugar
# ---------------------------- | --------------- | ----------------------------
# Marcos, Científico de Datos  | Julio de 2020   | Ciudad de México, México

# %% [markdown]
# Supongamos que tenemos un Excel en donde estamos registrando las ventas de nuestro negocio de bicicletas.

# %%
from IPython.display import Image
Image(filename='../images/Excel.png', width=600)

# %%
Image(filename='../images/guardar_como.png', width=600)

# %% [markdown]
# # Cargamos nuestro archivo

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
Image(filename='../images/pandas.png')

# %%
Image(filename='../images/install_pandas.png')

# %%
df = pd.read_csv('../data/bicicletas.csv')

# %%
df.head()
# Out:
#   vendedor  bicicletas  monto      fecha
# 0        A          10     50  01-ene-20
# 1        B           1      5  01-ene-20
# 2        C           3     15  01-ene-20
# 3        D           2     10  01-ene-20
# 4        A           0      0  03-ene-20

# %%
df.groupby('vendedor').sum()
# Out:
#           bicicletas  monto
# vendedor
# A                 13     65
# B                  5     25
# C                 11     55
# D                  7     35

# %%
df.groupby('vendedor').sum().plot(kind='bar');

# %%
df.groupby('fecha').sum().plot();

# %% [markdown]
# Se ve un descenso en el número de ventas, **¿QUÉ ESTARÁ PASANDO?**

# %% [markdown]
# ## ¿Puedo cargar archivos de Excel con pandas?

# %%
df = pd.read_excel('../data/bicicletas.xlsx', engine='openpyxl')

# %%
df.head()
# Out:
#   vendedor  bicicletas  monto      fecha
# 0        A          10     50 2020-01-01
# 1        B           1      5 2020-01-01
# 2        C           3     15 2020-01-01
# 3        D           2     10 2020-01-01
# 4        A           0      0 2020-01-03

# %% [markdown]
# Y puedo hacer lo mismo...
